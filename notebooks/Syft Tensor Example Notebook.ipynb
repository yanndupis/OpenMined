# %%
import syft
import syft.nn as nn
import syft.controller
import imp
imp.reload(syft.controller)
imp.reload(syft.nn)
imp.reload(syft)

import numpy as np
from syft import FloatTensor

# %%
# create tensors
data = np.array([-1,-2,3,4,5,-6]).astype('float')
a = FloatTensor(data)
b = FloatTensor(np.array([[-100,-200,300],[400,500,-600]]).astype('float'))
c = FloatTensor(np.array([-30,-32,33,34,35,-36]).astype('float'))

# %%
out = a.view_(2,3)

# %%
out
# Out:
# [[-1. -2.  3.]
#  [ 4.  5. -6.]]
# [syft.FloatTensor:165 grad:None size:2x3]

# %%
# using view_as should return new tensor with shape of given tensor
a.view_as(b)
# should be
#[[-1. -2.  3.]
# [ 4.  5. -6.]]
# Out:
# [[-1. -2.  3.]
#  [ 4.  5. -6.]]
# [syft.FloatTensor:168 grad:None size:2x3]

# %%
b.view_as(c)
# should be
# [-100. -200.  300.  400.  500. -600.]
# Out:
# [-100. -200.  300.  400.  500. -600.]
# [syft.FloatTensor:169 grad:None size:6]

# %%
c.view_as(b)
# should be
#[[-30. -32.  33.]
# [ 34.  35. -36.]]
# Out:
# [[-30. -32.  33.]
#  [ 34.  35. -36.]]
# [syft.FloatTensor:170 grad:None size:2x3]

# %%
d = b.view_as(c)
# d should be [-100. -200.  300.  400.  500. -600.]
d
# Out:
# [-100. -200.  300.  400.  500. -600.]
# [syft.FloatTensor:171 grad:None size:6]

# %% [markdown]
# ### CPU vs GPU

# %%
gpu = False

# %% [markdown]
# ### Absolute Value

# %%
a = FloatTensor(data)

if(gpu):
    a.gpu()

# %%
b = a.abs()
b
# Out:
# [ 1.  2.  3.  4.  5.  6.]
# [syft.FloatTensor:173 grad:None size:6]

# %%
a = FloatTensor(data)
if(gpu):
    a.gpu()

# %%
a
# Out:
# [-1. -2.  3.  4.  5. -6.]
# [syft.FloatTensor:174 grad:None size:6]

# %%
a.abs_()
# Out:
# [ 1.  2.  3.  4.  5.  6.]
# [syft.FloatTensor:174 grad:None size:6]

# %%
a.id
# Out:
# 174

# %% [markdown]
# ### Addition

# %%
a = FloatTensor(data)
if(gpu):
    a.gpu()

# %%
a = a + a
a
# Out:
# [ -2.  -4.   6.   8.  10. -12.]
# [syft.FloatTensor:176 grad:None size:6]

# %%
a += a
a
# Out:
# [ -4.  -8.  12.  16.  20. -24.]
# [syft.FloatTensor:176 grad:None size:6]

# %%
a = a + 3
a
# Out:
# [ -1.  -5.  15.  19.  23. -21.]
# [syft.FloatTensor:177 grad:None size:6]

# %%
a += 3
a
# Out:
# [  2.  -2.  18.  22.  26. -18.]
# [syft.FloatTensor:177 grad:None size:6]

# %% [markdown]
# ### Subtraction

# %%
a = FloatTensor(data)
b = FloatTensor(data * 2)
if(gpu):
    a.gpu()
    b.gpu()

# %%
a
# Out:
# [-1. -2.  3.  4.  5. -6.]
# [syft.FloatTensor:178 grad:None size:6]

# %%
b
# Out:
# [ -2.  -4.   6.   8.  10. -12.]
# [syft.FloatTensor:179 grad:None size:6]

# %%
a - b
# Out:
# [ 1.  2. -3. -4. -5.  6.]
# [syft.FloatTensor:180 grad:None size:6]

# %%
b - a
# Out:
# [-1. -2.  3.  4.  5. -6.]
# [syft.FloatTensor:181 grad:None size:6]

# %%
a - 1
# Out:
# [-2. -3.  2.  3.  4. -7.]
# [syft.FloatTensor:182 grad:None size:6]

# %%
b - 2
# Out:
# [ -4.  -6.   4.   6.   8. -14.]
# [syft.FloatTensor:183 grad:None size:6]

# %%
a -= 1
a
# Out:
# [-2. -3.  2.  3.  4. -7.]
# [syft.FloatTensor:178 grad:None size:6]

# %%
b -= 1
b
# Out:
# [ -3.  -5.   5.   7.   9. -13.]
# [syft.FloatTensor:179 grad:None size:6]

# %%
a -= b
a
# Out:
# [ 1.  2. -3. -4. -5.  6.]
# [syft.FloatTensor:178 grad:None size:6]

# %% [markdown]
# ## Multiplication

# %%
a = a * a
a
# Out:
# [  1.   4.   9.  16.  25.  36.]
# [syft.FloatTensor:184 grad:None size:6]

# %%
a *= a
a
# Out:
# [  1.00000000e+00   1.60000000e+01   8.10000000e+01   2.56000000e+02
#    6.25000000e+02   1.29600000e+03]
# [syft.FloatTensor:184 grad:None size:6]

# %%
a = a * 3
a
# Out:
# [  3.00000000e+00   4.80000000e+01   2.43000000e+02   7.68000000e+02
#    1.87500000e+03   3.88800000e+03]
# [syft.FloatTensor:185 grad:None size:6]

# %%
a *= 3
a
# Out:
# [  9.00000000e+00   1.44000000e+02   7.29000000e+02   2.30400000e+03
#    5.62500000e+03   1.16640000e+04]
# [syft.FloatTensor:185 grad:None size:6]

# %% [markdown]
# ### Divison

# %%
a
# Out:
# [  9.00000000e+00   1.44000000e+02   7.29000000e+02   2.30400000e+03
#    5.62500000e+03   1.16640000e+04]
# [syft.FloatTensor:185 grad:None size:6]

# %%
b
# Out:
# [ -3.  -5.   5.   7.   9. -13.]
# [syft.FloatTensor:179 grad:None size:6]

# %%
a = a/a
a
# Out:
# [ 1.  1.  1.  1.  1.  1.]
# [syft.FloatTensor:186 grad:None size:6]

# %%
b / a
# Out:
# [ -3.  -5.   5.   7.   9. -13.]
# [syft.FloatTensor:187 grad:None size:6]

# %%
a / b
# Out:
# [-0.3333333  -0.2         0.2         0.1428571   0.1111111  -0.07692308]
# [syft.FloatTensor:188 grad:None size:6]

# %%
a / 1
# Out:
# [ 1.  1.  1.  1.  1.  1.]
# [syft.FloatTensor:189 grad:None size:6]

# %%
b / 1
# Out:
# [ -3.  -5.   5.   7.   9. -13.]
# [syft.FloatTensor:190 grad:None size:6]

# %%
a /= b
a
# Out:
# [-0.3333333  -0.2         0.2         0.1428571   0.1111111  -0.07692308]
# [syft.FloatTensor:186 grad:None size:6]

# %%
b /= a
b
# Out:
# [   9.   25.   25.   49.   81.  169.]
# [syft.FloatTensor:179 grad:None size:6]

# %%
a /= a
a
# Out:
# [ 1.  1.  1.  1.  1.  1.]
# [syft.FloatTensor:186 grad:None size:6]

# %%
b /= 1
b
# Out:
# [   9.   25.   25.   49.   81.  169.]
# [syft.FloatTensor:179 grad:None size:6]

# %%
b /= 2
b
# Out:
# [  4.5  12.5  12.5  24.5  40.5  84.5]
# [syft.FloatTensor:179 grad:None size:6]

# %%
a *= 2

# %%
a
# Out:
# [ 2.  2.  2.  2.  2.  2.]
# [syft.FloatTensor:186 grad:None size:6]

# %%
a
# Out:
# [ 2.  2.  2.  2.  2.  2.]
# [syft.FloatTensor:186 grad:None size:6]
