# %%
import syft.syft as syft
import imp
imp.reload(syft)
from syft.syft import FloatTensor, SyftController
import numpy as np

# connect -- rerun this block if you make changes to the unity back-end
#         -- the controller is not yet smart enough to retry connection
#         -- on its own
sc = SyftController("bob")

# %%
# create tensors
data = np.array([-1,-2,3,4,5,-6]).astype('float')
a = sc.FloatTensor(data)

# %%
a.view_(2,3)
# Out:
# -1,	-2,	3,
# 4,	5,	-6,

# %% [markdown]
# ### CPU vs GPU

# %%
gpu = False

# %% [markdown]
# ### Absolute Value

# %%
a = sc.FloatTensor(data)

if(gpu):
    a.gpu()
# Out:
# FloatTensor.__init__: 4

# %%
b = a.abs()
b
# Out:
# FloatTensor.__init__: 5
# 1,	2,	3,	4,	5,	6,

# %%
a
# Out:
# -1,	-2,	3,	4,	5,	-6,

# %%
a = sc.FloatTensor(data)
if(gpu):
    a.gpu()
# Out:
# FloatTensor.__init__: 4

# %%
a.abs_()
# Out:
# 1,	2,	3,	4,	5,	6,

# %%
a.id
# Out:
# 4

# %% [markdown]
# ### Addition

# %%
a = sc.FloatTensor(data)
if(gpu):
    a.gpu()
# Out:
# FloatTensor.__init__: 5

# %%
a = a + a
a
# Out:
# -2,	-4,	6,	8,	10,	-12,

# %%
a += a
a
# Out:
# -4,	-8,	12,	16,	20,	-24,

# %%
a = a + 3
a
# Out:
# -1,	-5,	15,	19,	23,	-21,

# %%
a += 3
a
# Out:
# 2,	-2,	18,	22,	26,	-18,

# %% [markdown]
# ### Subtraction

# %%
a = sc.FloatTensor(data)
b = sc.FloatTensor(data * 2)
if(gpu):
    a.gpu()
    b.gpu()
# Out:
# FloatTensor.__init__: 8
# FloatTensor.__init__: 9

# %%
a
# Out:
# -1,	-2,	3,	4,	5,	-6,

# %%
b
# Out:
# -2,	-4,	6,	8,	10,	-12,

# %%
a - b
# Out:
# 1,	2,	-3,	-4,	-5,	6,

# %%
b - a
# Out:
# -1,	-2,	3,	4,	5,	-6,

# %%
a - 1
# Out:
# -2,	-3,	2,	3,	4,	-7,

# %%
b - 2
# Out:
# -4,	-6,	4,	6,	8,	-14,

# %%
a -= 1
a
# Out:
# -2,	-3,	2,	3,	4,	-7,

# %%
b -= 1
b
# Out:
# -3,	-5,	5,	7,	9,	-13,

# %%
a -= b
a
# Out:
# 1,	2,	-3,	-4,	-5,	6,

# %% [markdown]
# ## Multiplication

# %%
a = a * a
a
# Out:
# 1,	4,	9,	16,	25,	36,

# %%
a *= a
a
# Out:
# 1,	16,	81,	256,	624.9999,	1296,

# %%
a = a * 3
a
# Out:
# 3,	48,	243,	768,	1875,	3888.001,

# %%
a *= 3
a
# Out:
# 9,	144,	729,	2304,	5624.999,	11664,

# %% [markdown]
# ### Divison

# %%
a
# Out:
# 9,	144,	729,	2304,	5624.999,	11664,

# %%
b
# Out:
# -3,	-5,	5,	7,	9,	-13,

# %%
a/a
# Out:
# 1,	1,	1,	1,	1,	1,

# %%
b / a
# Out:
# -0.3333333,	-0.03472222,	0.006858711,	0.003038194,	0.0016,	-0.00111454,

# %%
a / b
# Out:
# -3,	-28.8,	145.8,	329.1429,	624.9999,	-897.231,

# %%
a / 1
# Out:
# 9,	144,	729,	2304,	5624.999,	11664,

# %%
b / 1
# Out:
# -3,	-5,	5,	7,	9,	-13,

# %%
a /= b
a
# Out:
# -3,	-28.8,	145.8,	329.1429,	624.9999,	-897.231,

# %%
b /= a
b
# Out:
# 1,	0.1736111,	0.03429355,	0.02126736,	0.0144,	0.01448902,

# %%
a /= a
a
# Out:
# 1,	1,	1,	1,	1,	1,

# %%
b /= 1
b
# Out:
# 1,	0.1736111,	0.03429355,	0.02126736,	0.0144,	0.01448902,

# %%
b /= 2
b
# Out:
# 0.5,	0.08680556,	0.01714678,	0.01063368,	0.007200001,	0.007244511,
